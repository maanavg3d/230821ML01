# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
fig = plt.figure(figsize=(12,3))
plt.scatter(df3['a'],df3['b'],c='red',edgecolors='black',s= 50)
plt.xlabel('a')
plt.ylabel('b')
_ = plt.xticks(np.arange(-0.2,1.4,0.2))
_ = plt.yticks(np.arange(-0.2,1.4,0.2))

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
fig = plt.figure()
plt.hist(df3['a'],edgecolor='black',color='blue')
plt.xlabel('a')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
fig = plt.figure()
plt.style.use('ggplot')
plt.hist(df3['a'],bins=25,edgecolor='white',alpha=0.4)
plt.xlabel('a')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
fig = plt.figure()
plt.subplots(1,2,sharey = True,)
plt.subplot(1,2,1)
plt.boxplot(df3['a'],labels='a')
plt.subplot(1,2,2)
plt.boxplot(df3['b'],labels='b')

# spacing, color, dotted
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218d514c490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218d514c400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218d514c940>],
#  'medians': [<matplotlib.lines.Line2D at 0x218c7bac610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218c7bacd00>],
#  'means': []}

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
fig = plt.figure()
df3['d'].plot.kde(alpha=0.5)
_ = plt.xticks(np.arange(-0.5,1.6,0.5))

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
fig = plt.figure()
df3['d'].plot.kde(lw=4,ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
fig = plt.figure()
x = range(0,30)
plt.fill_between(x,df3['a'][:30],alpha=0.3,edgecolor='black',label='a')
plt.fill_between(x,df3['b'][:30],alpha=0.3,edgecolor='black',label='b')
plt.fill_between(x,df3['c'][:30],alpha=0.3,edgecolor='black',label='c')
plt.fill_between(x,df3['d'][:30],alpha=0.3,edgecolor='black',label='d')
plt.legend()

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
fig = plt.figure()
y = np.linspace(0,3,30)
x = range(0,30)
plt.fill_between(x,df3['a'][:30],alpha=0.6,edgecolor='black',label='a')
plt.fill_between(x,df3['b'][:30],alpha=0.6,edgecolor='black',label='b')
plt.fill_between(x,df3['c'][:30],alpha=0.6,edgecolor='black',label='c')
plt.fill_between(x,df3['d'][:30],alpha=0.6,edgecolor='black',label='d')
plt.legend(bbox_to_anchor=(1.2,0.7))

# %% [markdown]
# # Great Job!
